# %%
from bs4 import BeautifulSoup
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
import platform
from langdetect import detect
import json
from tqdm import tqdm

# If browser is loading too fast, enable time.sleep option
# import time

options = webdriver.ChromeOptions()
#options.add_argument("headless")
options.add_experimental_option("excludeSwitches", ["enable-automation"])

# Choose right chromedriver of your OS

if platform.system() == "Windows":
    driverpath = os.getcwd() + "/chromedriver.exe"
else:
    driverpath = os.getcwd() + "/chromedriver"


def get_links(page, lang=True):

    url = "https://www.coursera.org/directory/courses?page=" + str(page)
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, "lxml")
    links = soup.findAll("a", {"class": "c-directory-link"}, href=True)

    course_name = []
    course_links = []
    for i in links:
        if detect(i.text) == "en":
            course_name.append(i.text)
            course_links.append("https://coursera.org" + i["href"])

    collected = {}
    for i in range(0, len(course_name)):
        collected[course_name[i]] = course_links[i]
    return collected

# %%
def crawl_add(url):
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, "lxml")


    if soup.findAll("div", {"class": "_1fpiay2"}) != []:
        enroll = soup.findAll("div", {"class": "_1fpiay2"})[0].findAll("span")[-1].text
        enroll = int(re.sub("[^0-9.]+", "", enroll))
    else:
        enroll = "None"

    if soup.findAll("div", {"class": "_bd90rg"}) != []:
        views = soup.findAll("div", {"class": "_bd90rg"})[0].findAll("span")[-1].text
        views = int(re.sub("[^0-9.]+", "", views))
    else:
        views = "None"

    if soup.findAll("div", {"class": "instructor-wrapper"}) != []:
        instructor_infos = soup.findAll("div", {"class": "instructor-wrapper"})
        instructor_information = {}
        for i in instructor_infos:
            instructor_info = i
            instructor_name = instructor_info.find("h3").text
            instructor_title = instructor_info.find(
                "span", {"class": "instructor-title"}
            ).text
            try:
                instructor_department = instructor_info.find(
                    "div", {"class": "instructor-department caption-text color-black"}
                ).text
            except AttributeError:
                instructor_department = "None"
            try:
                detail = instructor_info.find("div", {"class": "instructor-expertise"})
            except AttributeError:
                detail = None

            if detail != None:
                learners = detail.find("span").text
                learners = int(re.sub("[^0-9.]+", "", learners))
                courses = detail.find("div", {"class": "courses-count"}).text
                courses = int(re.sub("[^0-9.]+", "", courses))
            else:
                learners = "None"
                courses = "None"

            instructor_information[instructor_name] = {
                "Instructor_title": instructor_title,
                "Instructor_department": instructor_department,
                "Learners": learners,
                "Open_courses": courses,
            }
    else:
        instructor_information = "None"
    return {
        "Enroll": enroll,
        "Views": views,
        "Instructor_info": instructor_information,
    }

# %%
driver = webdriver.Chrome(driverpath, chrome_options=options)
data = {}

start = input("Which page to start?: ")
page = input("How many pages to crawl? (Max 194...): ")
for i in range(int(start), int(page) + 1):

    print("Start scraping...")

    links = get_links(i, lang=True)  # Detect language, and if not English, skip
    names = list(links.keys())

    for c in tqdm(range(0, len(names))):
        course = names[c]
        link = links[course]
        data[course] = crawl_add(link)

    if i % 10 == 0:
        print("Page {} out of {}...".format(i, page))
        # backup:
        print("Saved backup")
# Out:
# /Users/HongSukhyun/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: use options instead of chrome_options
#   """Entry point for launching an IPython kernel.
# Which page to start?: 106
# How many pages to crawl? (Max 194...): 106
# Start scraping...
# 100%|██████████| 33/33 [01:23<00:00,  2.54s/it]

# %%
data
# Out:
# {'Introduction to Project Management (Coursera Project Network)': {'Enroll': 31875,
#   'Views': 'None',
#   'Instructor_info': {'Megan Peck': {'Instructor_title': 'Project Manager',
#     'Instructor_department': 'None',
#     'Learners': 31875,
#     'Open_courses': 1}}},
#  'Introduction to Project Management with ClickUp (Coursera Project Network)': {'Enroll': 10995,
#   'Views': 'None',
#   'Instructor_info': {'Abby Saey': {'Instructor_title': '',
#     'Instructor_department': 'Freedom Learning Group',
#     'Learners': 43756,
#     'Open_courses': 18}}},
#  'Introduction to Psychology (University of Toronto)': {'Enroll': 343928,
#   'Views': 200689,
#   'Instructor_info': {'Steve Joordens': {'Instructor_title': 'Professor',
#     'Instructor_department': 'Department of Psychology',
#     'Learners': 489827,
#     'Open_courses': 3}}},
#  'Introduction to Psychology (Yale University)': {'Enroll': 608457,
#   'Views': 1086040,
#   'Instructor_info': {'Paul Bloom': {'Instructor_title': 'Brooks and Suzanne Ragen Professor of Psychology and Cognitive Science at Yale University',
#     'Instructor_department': 'Psychology',
#     'Learners': 691775,
#     'Open_courses': 2}}},
#  'Introduction to Public Speaking (University of Washington)': {'Enroll': 173732,
#   'Views': 327643,
#   'Instructor_info': {'Dr. Matt McGarrity': {'Instructor_title': 'Principal Lecturer',
#     'Instructor_department': 'UW Department of Communication',
#     'Learners': 626134,
#     'Open_courses': 8}}},
#  'Introduction to Python (Coursera Project Network)': {'Enroll': 26114,
#   'Views': 'None',
#   'Instructor_info': {'David Dalsveen': {'Instructor_title': 'Subject Matter Expert',
#     'Instructor_department': 'Freedom Learning Group',
#     'Learners': 69244,
#     'Open_courses': 64}}},
#  'Introduction to Python Programming (University of Pennsylvania)': {'Enroll': 6122,
#   'Views': 122770,
#   'Instructor_info': {'Brandon Krakowsky': {'Instructor_title': 'Lecturer',
#     'Instructor_department': 'School of Engineering and Applied Science',
#     'Learners': 8941,
#     'Open_courses': 6}}},
#  'Introduction to R: Basic R syntax (Coursera Project Network)': {'Enroll': 'None',
#   'Views': 'None',
#   'Instructor_info': {'Nicole Baerg': {'Instructor_title': '',
#     'Instructor_department': 'None',
#     'Learners': 120,
#     'Open_courses': 5}}},
#  'Introduction to Recommender Systems:  Non-Personalized and Content-Based (University of Minnesota)': {'Enroll': 28999,
#   'Views': 18303,
#   'Instructor_info': {'Joseph A Konstan': {'Instructor_title': 'Distinguished McKnight Professor and Distinguished University Teaching Professor',
#     'Instructor_department': 'Computer Science and Engineering',
#     'Learners': 161152,
#     'Open_courses': 11},
#    'Michael D. Ekstrand': {'Instructor_title': 'Assistant Professor',
#     'Instructor_department': 'Dept. of Computer Science, Boise State University',
#     'Learners': 97678,
#     'Open_courses': 6}}},
#  'Introduction to Reinforcement Learning in Python (Coursera Project Network)': {'Enroll': 2408,
#   'Views': 'None',
#   'Instructor_info': {'Charles Ivan Niswander II': {'Instructor_title': 'Machine Learning Engineer and Python/C# Developer and IT Subject Matter Expert',
#     'Instructor_department': 'Freedom Learning Group',
#     'Learners': 20429,
#     'Open_courses': 22}}},
#  'Introduction to Relational Database and SQL (Coursera Project Network)': {'Enroll': 23827,
#   'Views': 'None',
#   'Instructor_info': {'Harrison Kong': {'Instructor_title': 'Subject Matter Expert / Instructor',
#     'Instructor_department': 'None',
#     'Learners': 86133,
#     'Open_courses': 31}}},
#  'Introduction to Relational Databases (RDBMS) (IBM)': {'Enroll': 'None',
#   'Views': 4049,
#   'Instructor_info': {'Rav Ahuja': {'Instructor_title': 'Global Program Director ',
#     'Instructor_department': 'IBM Skills Network',
#     'Learners': 655207,
#     'Open_courses': 22},
#    'Lin Joyner': {'Instructor_title': 'Senior Instructional Designer & Content Developer',
#     'Instructor_department': 'Skill-Up Technologies',
#     'Learners': 169,
#     'Open_courses': 1},
#    'Rose Malcolm': {'Instructor_title': 'Senior Instructional Designer & Content Developer',
#     'Instructor_department': 'Skill-Up Technologies',
#     'Learners': 169,
#     'Open_courses': 1},
#    'Sandip Saha Joy': {'Instructor_title': 'Cognitive Data Scientist',
#     'Instructor_department': 'IBM Developer Skills Network',
#     'Learners': 201845,
#     'Open_courses': 7}}},
#  'Introduction to Reproduction (Northwestern University)': {'Enroll': 21813,
#   'Views': 13301,
#   'Instructor_info': {'Teresa K. Woodruff, Ph.D.': {'Instructor_title': 'Vice Chair for Research, Department of Obstetrics and Gynecology, Thomas J. Watkins Professor of Obstetrics and Gynecology, Director, Women’s Health Research Institute',
#     'Instructor_department': 'Feinberg School of Medicine',
#     'Learners': 21813,
#     'Open_courses': 1}}},
#  'Introduction to Research for Essay Writing (University of California, Irvine)': {'Enroll': 69527,
#   'Views': 34445,
#   'Instructor_info': {'Tamy Chapman': {'Instructor_title': 'Instructor, International Programs',
#     'Instructor_department': 'University of California Irvine Division of Continuing Education',
#     'Learners': 1129391,
#     'Open_courses': 22},
#    'Helen Nam': {'Instructor_title': 'Instructor',
#     'Instructor_department': 'International Programs, UCI Extension',
#     'Learners': 833115,
#     'Open_courses': 12}}},
#  'Introduction to Risk Management (University of California, Irvine)': {'Enroll': 'None',
#   'Views': 13386,
#   'Instructor_info': {'Qasim Ijaz': {'Instructor_title': 'Offensive Security Lead',
#     'Instructor_department': 'None',
#     'Learners': 711,
#     'Open_courses': 2}}},
#  'Introduction to Search Engine Optimization (University of California, Davis)': {'Enroll': 186169,
#   'Views': 172448,
#   'Instructor_info': {'Rebekah May': {'Instructor_title': 'SEO Manager & Lead SEO Instructor, Lead Qual',
#     'Instructor_department': 'UC Davis Division of Continuing and Professional Education',
#     'Learners': 222053,
#     'Open_courses': 4}}},
#  'Introduction to Search Techniques in Python: Binary Search (Coursera Project Network)': {'Enroll': 'None',
#   'Views': 'None',
#   'Instructor_info': {'Dalya Faizy': {'Instructor_title': 'Mechatronics Engineer',
#     'Instructor_department': 'Engineering and Material Sciences ',
#     'Learners': 54,
#     'Open_courses': 3}}},
#  'Introduction to Self-Determination Theory: An approach to motivation, development and wellness (University of Rochester)': {'Enroll': 35499,
#   'Views': 47529,
#   'Instructor_info': {'Richard Ryan': {'Instructor_title': 'Professor of Psychology, Psychiatry & Education',
#     'Instructor_department': 'Clinical and Social Sciences  in Psychology',
#     'Learners': 35499,
#     'Open_courses': 1}}},
#  'Introduction to Self-Driving Cars (University of Toronto)': {'Enroll': 99639,
#   'Views': 169741,
#   'Instructor_info': {'Steven Waslander': {'Instructor_title': 'Associate Professor',
#     'Instructor_department': 'Aerospace Studies',
#     'Learners': 110452,
#     'Open_courses': 4},
#    'Jonathan Kelly': {'Instructor_title': 'Associate Professor',
#     'Instructor_department': 'Aerospace Studies',
#     'Learners': 107242,
#     'Open_courses': 3}}},
#  'Introduction to Semiconductor Devices 1 (Korea Advanced Institute of Science and Technology(KAIST))': {'Enroll': 2361,
#   'Views': 7491,
#   'Instructor_info': {'Keon Jae Lee': {'Instructor_title': 'Introduction to Semiconductor Devices',
#     'Instructor_department': 'Material Science Engineering',
#     'Learners': 2750,
#     'Open_courses': 2}}},
#  'Introduction to Semiconductor Devices 2 (Korea Advanced Institute of Science and Technology(KAIST))': {'Enroll': 'None',
#   'Views': 2465,
#   'Instructor_info': {'Keon Jae Lee': {'Instructor_title': 'Introduction to Semiconductor Devices',
#     'Instructor_department': 'Material Science Engineering',
#     'Learners': 2750,
#     'Open_courses': 2}}},
#  'Introduction to Sentiment Analysis in R with quanteda (Coursera Project Network)': {'Enroll': 'None',
#   'Views': 'None',
#   'Instructor_info': {'Nicole Baerg': {'Instructor_title': '',
#     'Instructor_department': 'None',
#     'Learners': 120,
#     'Open_courses': 5}}},
#  'Introduction to Shader Graphics with OpenGL (Coursera Project Network)': {'Enroll': 'None',
#   'Views': 'None',
#   'Instructor_info': {'Youssef Abusamra': {'Instructor_title': '',
#     'Instructor_department': 'None',
#     'Learners': 'None',
#     'Open_courses': 'None'}}},
#  'Introduction to Social Media Analytics (Emory University)': {'Enroll': 18538,
#   'Views': 12796,
#   'Instructor_info': {'David Schweidel': {'Instructor_title': 'Associate Professor of Marketing',
#     'Instructor_department': 'Goizueta Business School',
#     'Learners': 48152,
#     'Open_courses': 6}}},
#  'Introduction to Social Media Marketing (Facebook)': {'Enroll': 91865,
#   'Views': 840906,
#   'Instructor_info': {'Anke AudenaertTop Instructor': {'Instructor_title': 'CEO & Co-Founder Aptly, Adj. Professor, UCLA Anderson School of Management',
#     'Instructor_department': 'None',
#     'Learners': 102225,
#     'Open_courses': 12}}},
#  'Introduction to Software Product Management (University of Alberta)': {'Enroll': 91411,
#   'Views': 49114,
#   'Instructor_info': {'Kenny Wong': {'Instructor_title': 'Associate Professor',
#     'Instructor_department': 'Computing Science, Faculty of Science',
#     'Learners': 251735,
#     'Open_courses': 11}}},
#  'Introduction to Software Testing (University of Minnesota)': {'Enroll': 26899,
#   'Views': 126499,
#   'Instructor_info': {'Sanjai Rayadurgam': {'Instructor_title': 'Director',
#     'Instructor_department': 'University of Minnesota Software Engineering Center',
#     'Learners': 27620,
#     'Open_courses': 2},
#    'Kevin Wendt': {'Instructor_title': 'Director of Graduate Studies, Software Engineering',
#     'Instructor_department': 'Department of Computer Science and Engineering ',
#     'Learners': 70357,
#     'Open_courses': 6}}},
#  'Introduction to Spatial SQL with PostGIS (Coursera Project Network)': {'Enroll': 'None',
#   'Views': 'None',
#   'Instructor_info': {'Abdishakur Hassan': {'Instructor_title': 'Instructor',
#     'Instructor_department': 'None',
#     'Learners': 983,
#     'Open_courses': 5}}},
#  'Introduction to Spreadsheets and Models (University of Pennsylvania)': {'Enroll': 86920,
#   'Views': 52376,
#   'Instructor_info': {'Don Huesman': {'Instructor_title': 'Managing Director, Wharton Online',
#     'Instructor_department': 'Innovation Group- Wharton School',
#     'Learners': 87019,
#     'Open_courses': 2}}},
#  'Introduction to Statistical Analysis:  Hypothesis Testing (SAS)': {'Enroll': 2965,
#   'Views': 12409,
#   'Instructor_info': {'Jordan Bakerman': {'Instructor_title': 'Analytical Training Consultant',
#     'Instructor_department': 'Education',
#     'Learners': 23270,
#     'Open_courses': 4}}},
#  'Introduction to Statistics & Data Analysis in Public Health (Imperial College London)': {'Enroll': 26306,
#   'Views': 61595,
#   'Instructor_info': {'Alex Bottle': {'Instructor_title': 'Professor Medical Statistics',
#     'Instructor_department': 'School of Public Health',
#     'Learners': 33401,
#     'Open_courses': 6}}},
#  'Introduction to Statistics (Stanford University)': {'Enroll': 2087,
#   'Views': 15179,
#   'Instructor_info': {'Guenther Walther': {'Instructor_title': 'Professor of Statistics',
#     'Instructor_department': 'Department of Statistics',
#     'Learners': 2087,
#     'Open_courses': 1}}},
#  'Introduction to Structured Query Language (SQL) (University of Michigan)': {'Enroll': 108925,
#   'Views': 122967,
#   'Instructor_info': {'Charles Russell Severance': {'Instructor_title': 'Clinical Professor',
#     'Instructor_department': 'School of Information',
#     'Learners': 2810232,
#     'Open_courses': 43}}}}

# %%
# Save as json file
with open("additional_data.json", "w", encoding="utf-8") as json_file:
    json.dump(data, json_file)
